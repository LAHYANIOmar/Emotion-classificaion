# %% [markdown]
# <a href="https://colab.research.google.com/github/LAHYANIOmar/Emotion-classificaion/blob/main/face_emotion_recognition_resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this Notebook, We'll train a CNN model that is similar to ResNet50 in architecture.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/fer2013/fer2013.csv
# /kaggle/input/rrjjjj/ggggggg.jpg
# /kaggle/input/rrjjjj/ghgffg.jpg
# /kaggle/input/rrjjjj/fgfg.jpg
# /kaggle/input/rrjjjj/ffffdddd.jpg
# /kaggle/input/rrjjjj/zazza.jpg
# /kaggle/input/rrjjjj/zerf.jpg
# /kaggle/input/rrjjjj/hhjhjhjhjhj.jpg
# /kaggle/input/rrjjjj/Happy_guy.jpg

# %% [markdown]
# **Let us first import the needed packages.**

# %%
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

# %% [markdown]
# **Create a directory to save our generated models.**

# %%
os.mkdir("./model")

# %% [markdown]
# **Define the identity block helper function.**

# %%
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block

    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network

    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """

    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. You'll need this later to add back to the main path.
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)


    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)

    return X

# %% [markdown]
# **Define the covolutional block helper function.**

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block4

    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used

    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """

    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(F2, (f, f), strides = (1,1), name = conv_name_base + '2b',padding = 'same', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(F3, (1, 1), strides = (1,1), name = conv_name_base + '2c',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)

    return X

# %% [markdown]
# **Merge them together into the model.**

# %%
def Net50(input_shape = (48,48,1), classes = 7):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """

    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)


    # Zero-Padding
    #X = ZeroPadding2D((1, 1))(X_input)
    X = X_input
    # Stage 1

    X = Conv2D(8, (3, 3), strides = (1, 1), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    # removed maxpool
    #X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [32, 32, 128], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='b')
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='c')


    # Stage 3
    X = convolutional_block(X, f = 3, filters = [64,64,256], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [64,64,256], stage=3, block='b')
    X = identity_block(X, 3, [64,64,256], stage=3, block='c')
    X = identity_block(X, 3, [64,64,256], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='d')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='e')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='f')

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='c')

    # AVGPOOL .
    X = AveragePooling2D((2,2), name='avg_pool')(X)

    # output layer
    X = Flatten()(X)
    X = Dense(512, activation = 'relu', name='fc1024' , kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)


    # Create model
    model = Model(inputs = X_input, outputs = X, name='Net50')

    return model

# %% [markdown]
# **Load and preprocess the dataset.**

# %%
import cv2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf

dataset_path = '../input/fer2013/fer2013.csv'
image_size=(48,48)
batch_size = 32

def load_fer2013():
    data = pd.read_csv(dataset_path)
    data = (data[data['pixels'].notnull()])
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = (data['emotion'])#.values
    return faces, emotions

def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x

faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)
#Data Augumentation
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        shear_range = 10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)

# %%
faces[3].shape
# Out:
# (48, 48, 1)

# %% [markdown]
# **Declaring hyperparameters and callbacks.**

# %%
batch_size = 32
num_epochs = 150
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 25
base_path = './model/'
l2_regularization=0.01

# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/2), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]

# %% [markdown]
# **Compile the model.**

# %%
from keras.optimizers import Adam, SGD
model = Net50(input_shape = (48, 48, 1), classes = 7)
optimizer = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
model.compile(optimizer= optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "Net50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 46, 46, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 46, 46, 8)    32          conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 46, 46, 8)    0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 46, 46, 32)   288         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 46, 46, 32)   128         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 46, 46, 32)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 46, 46, 32)   9248        activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 46, 46, 32)   128         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 46, 46, 32)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 46, 46, 128)  1152        activation[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 46, 46, 128)  4224        activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 46, 46, 128)  512         res2a_branch1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 46, 46, 128)  512         res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 46, 46, 128)  0           bn2a_branch1[0][0]
#                                                                  bn2a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 46, 46, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 46, 46, 32)   4128        activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 46, 46, 32)   128         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 46, 46, 32)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 46, 46, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 46, 46, 32)   128         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 46, 46, 32)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 46, 46, 128)  4224        activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 46, 46, 128)  512         res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 46, 46, 128)  0           activation_3[0][0]
#                                                                  bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 46, 46, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 46, 46, 32)   4128        activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 46, 46, 32)   128         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 46, 46, 32)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 46, 46, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 46, 46, 32)   128         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 46, 46, 32)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 46, 46, 128)  4224        activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 46, 46, 128)  512         res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 46, 46, 128)  0           activation_6[0][0]
#                                                                  bn2c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 46, 46, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 23, 23, 64)   8256        activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 23, 23, 64)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 23, 23, 64)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 23, 23, 256)  33024       activation_9[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 23, 23, 256)  1024        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 23, 23, 256)  0           bn3a_branch1[0][0]
#                                                                  bn3a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 23, 23, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 23, 23, 64)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 23, 23, 64)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 23, 23, 256)  0           activation_12[0][0]
#                                                                  bn3b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 23, 23, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 23, 23, 64)   0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 23, 23, 64)   0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 23, 23, 256)  0           activation_15[0][0]
#                                                                  bn3c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 23, 23, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 23, 23, 64)   16448       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 23, 23, 64)   256         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 23, 23, 64)   0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 23, 23, 64)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 23, 23, 64)   256         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 23, 23, 64)   0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 23, 23, 256)  16640       activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 23, 23, 256)  1024        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 23, 23, 256)  0           activation_18[0][0]
#                                                                  bn3d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 23, 23, 256)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 12, 12, 128)  32896       activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 12, 12, 128)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 12, 12, 128)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 12, 12, 512)  131584      activation_21[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 12, 12, 512)  2048        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 512)  0           bn4a_branch1[0][0]
#                                                                  bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 12, 12, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 12, 128)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 512)  0           activation_24[0][0]
#                                                                  bn4b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 512)  0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 12, 12, 512)  0           activation_27[0][0]
#                                                                  bn4c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 128)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 512)  0           activation_30[0][0]
#                                                                  bn4d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 128)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 512)  0           activation_33[0][0]
#                                                                  bn4e_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 512)  0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 12, 12, 128)  65664       activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 12, 12, 128)  512         res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 12, 12, 128)  147584      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 12, 12, 128)  512         res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 12, 12, 512)  66048       activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 12, 12, 512)  2048        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 512)  0           activation_36[0][0]
#                                                                  bn4f_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 512)  0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 6, 6, 256)    131328      activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 6, 6, 256)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 6, 6, 256)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 6, 6, 1024)   525312      activation_39[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 6, 6, 1024)   4096        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 6, 6, 1024)   0           bn5a_branch1[0][0]
#                                                                  bn5a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 6, 6, 1024)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 6, 6, 256)    262400      activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 6, 6, 256)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 6, 6, 256)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 6, 6, 1024)   0           activation_42[0][0]
#                                                                  bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 6, 6, 1024)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 6, 6, 256)    262400      activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 6, 6, 256)    1024        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 6, 6, 256)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 6, 6, 256)    590080      activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 6, 6, 256)    1024        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 6, 6, 256)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 6, 6, 1024)   263168      activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 6, 6, 1024)   4096        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 6, 6, 1024)   0           activation_45[0][0]
#                                                                  bn5c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 6, 6, 1024)   0           add_15[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 3, 3, 1024)   0           activation_48[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc1024 (Dense)                  (None, 512)          4719104     flatten[0][0]
# __________________________________________________________________________________________________
# fc7 (Dense)                     (None, 7)            3591        fc1024[0][0]
# ==================================================================================================
# Total params: 10,646,583
# Trainable params: 10,620,071
# Non-trainable params: 26,512
# __________________________________________________________________________________________________

# %%
history = model.fit(data_generator.flow(xtrain, ytrain,),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data= (xtest,ytest))
# Out:
# Epoch 1/150
# 898/897 [==============================] - ETA: 0s - loss: 2.0119 - accuracy: 0.2545
# Epoch 00001: val_loss improved from inf to 1.82271, saving model to ./model/_mini_XCEPTION.01-0.28.hdf5
# 898/897 [==============================] - 92s 103ms/step - loss: 2.0119 - accuracy: 0.2545 - val_loss: 1.8227 - val_accuracy: 0.2750
# Epoch 2/150
# 898/897 [==============================] - ETA: 0s - loss: 1.5871 - accuracy: 0.3711
# Epoch 00002: val_loss improved from 1.82271 to 1.73655, saving model to ./model/_mini_XCEPTION.02-0.33.hdf5
# 898/897 [==============================] - 93s 104ms/step - loss: 1.5871 - accuracy: 0.3711 - val_loss: 1.7366 - val_accuracy: 0.3306
# Epoch 3/150
# 898/897 [==============================] - ETA: 0s - loss: 1.4204 - accuracy: 0.4495
# Epoch 00003: val_loss did not improve from 1.73655
# 898/897 [==============================] - 92s 103ms/step - loss: 1.4204 - accuracy: 0.4495 - val_loss: 4.4089 - val_accuracy: 0.2005
# Epoch 4/150
# 898/897 [==============================] - ETA: 0s - loss: 1.3198 - accuracy: 0.4930
# Epoch 00004: val_loss did not improve from 1.73655
# 898/897 [==============================] - 92s 103ms/step - loss: 1.3198 - accuracy: 0.4930 - val_loss: 1.7559 - val_accuracy: 0.3632
# Epoch 5/150
# 898/897 [==============================] - ETA: 0s - loss: 1.2510 - accuracy: 0.5218
# Epoch 00005: val_loss improved from 1.73655 to 1.26836, saving model to ./model/_mini_XCEPTION.05-0.51.hdf5
# 898/897 [==============================] - 93s 104ms/step - loss: 1.2510 - accuracy: 0.5218 - val_loss: 1.2684 - val_accuracy: 0.5141
# Epoch 6/150
# 898/897 [==============================] - ETA: 0s - loss: 1.2056 - accuracy: 0.5418
# Epoch 00006: val_loss did not improve from 1.26836
# 898/897 [==============================] - 93s 104ms/step - loss: 1.2056 - accuracy: 0.5418 - val_loss: 1.3235 - val_accuracy: 0.4929
# Epoch 7/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1654 - accuracy: 0.5554
# Epoch 00007: val_loss improved from 1.26836 to 1.21393, saving model to ./model/_mini_XCEPTION.07-0.54.hdf5
# 898/897 [==============================] - 94s 104ms/step - loss: 1.1654 - accuracy: 0.5554 - val_loss: 1.2139 - val_accuracy: 0.5418
# Epoch 8/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1317 - accuracy: 0.5719
# Epoch 00008: val_loss improved from 1.21393 to 1.17075, saving model to ./model/_mini_XCEPTION.08-0.56.hdf5
# 898/897 [==============================] - 94s 105ms/step - loss: 1.1317 - accuracy: 0.5719 - val_loss: 1.1707 - val_accuracy: 0.5571
# Epoch 9/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1018 - accuracy: 0.5812
# Epoch 00009: val_loss improved from 1.17075 to 1.15965, saving model to ./model/_mini_XCEPTION.09-0.57.hdf5
# 898/897 [==============================] - 94s 104ms/step - loss: 1.1018 - accuracy: 0.5812 - val_loss: 1.1597 - val_accuracy: 0.5692
# Epoch 10/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0850 - accuracy: 0.5898
# Epoch 00010: val_loss did not improve from 1.15965
# 898/897 [==============================] - 93s 104ms/step - loss: 1.0850 - accuracy: 0.5898 - val_loss: 1.1611 - val_accuracy: 0.5680
# Epoch 11/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0674 - accuracy: 0.5970
# Epoch 00011: val_loss improved from 1.15965 to 1.15698, saving model to ./model/_mini_XCEPTION.11-0.56.hdf5
# 898/897 [==============================] - 94s 105ms/step - loss: 1.0674 - accuracy: 0.5970 - val_loss: 1.1570 - val_accuracy: 0.5644
# Epoch 12/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0479 - accuracy: 0.6072
# Epoch 00012: val_loss improved from 1.15698 to 1.11090, saving model to ./model/_mini_XCEPTION.12-0.59.hdf5
# 898/897 [==============================] - 94s 105ms/step - loss: 1.0479 - accuracy: 0.6072 - val_loss: 1.1109 - val_accuracy: 0.5882
# Epoch 13/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0311 - accuracy: 0.6111
# Epoch 00013: val_loss did not improve from 1.11090
# 898/897 [==============================] - 93s 104ms/step - loss: 1.0311 - accuracy: 0.6111 - val_loss: 1.1439 - val_accuracy: 0.5871
# Epoch 14/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0095 - accuracy: 0.6209
# Epoch 00014: val_loss improved from 1.11090 to 1.08732, saving model to ./model/_mini_XCEPTION.14-0.60.hdf5
# 898/897 [==============================] - 94s 105ms/step - loss: 1.0095 - accuracy: 0.6209 - val_loss: 1.0873 - val_accuracy: 0.6042
# Epoch 15/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9942 - accuracy: 0.6271
# Epoch 00015: val_loss improved from 1.08732 to 1.04836, saving model to ./model/_mini_XCEPTION.15-0.60.hdf5
# 898/897 [==============================] - 94s 104ms/step - loss: 0.9942 - accuracy: 0.6271 - val_loss: 1.0484 - val_accuracy: 0.6048
# Epoch 16/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9824 - accuracy: 0.6302
# Epoch 00016: val_loss improved from 1.04836 to 1.00612, saving model to ./model/_mini_XCEPTION.16-0.62.hdf5
# 898/897 [==============================] - 94s 104ms/step - loss: 0.9824 - accuracy: 0.6302 - val_loss: 1.0061 - val_accuracy: 0.6227
# Epoch 17/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9659 - accuracy: 0.6372
# Epoch 00017: val_loss did not improve from 1.00612
# 898/897 [==============================] - 93s 104ms/step - loss: 0.9659 - accuracy: 0.6372 - val_loss: 1.0255 - val_accuracy: 0.6211
# Epoch 18/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9544 - accuracy: 0.6431
# Epoch 00018: val_loss did not improve from 1.00612
# 898/897 [==============================] - 93s 103ms/step - loss: 0.9544 - accuracy: 0.6431 - val_loss: 1.1206 - val_accuracy: 0.5907
# Epoch 19/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9460 - accuracy: 0.6463
# Epoch 00019: val_loss did not improve from 1.00612
# 898/897 [==============================] - 93s 103ms/step - loss: 0.9460 - accuracy: 0.6463 - val_loss: 1.0384 - val_accuracy: 0.6183
# Epoch 20/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9290 - accuracy: 0.6506
# Epoch 00020: val_loss did not improve from 1.00612
# 898/897 [==============================] - 93s 104ms/step - loss: 0.9290 - accuracy: 0.6506 - val_loss: 1.0618 - val_accuracy: 0.6027
# Epoch 21/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9185 - accuracy: 0.6566
# Epoch 00021: val_loss did not improve from 1.00612
# 898/897 [==============================] - 92s 103ms/step - loss: 0.9185 - accuracy: 0.6566 - val_loss: 1.0319 - val_accuracy: 0.6227
# Epoch 22/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9083 - accuracy: 0.6606
# Epoch 00022: val_loss improved from 1.00612 to 1.00049, saving model to ./model/_mini_XCEPTION.22-0.63.hdf5
# 898/897 [==============================] - 93s 104ms/step - loss: 0.9083 - accuracy: 0.6606 - val_loss: 1.0005 - val_accuracy: 0.6287
# Epoch 23/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8992 - accuracy: 0.6631
# Epoch 00023: val_loss did not improve from 1.00049
# 898/897 [==============================] - 93s 104ms/step - loss: 0.8992 - accuracy: 0.6631 - val_loss: 1.0048 - val_accuracy: 0.6322
# Epoch 24/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8822 - accuracy: 0.6688
# Epoch 00024: val_loss did not improve from 1.00049
# 898/897 [==============================] - 93s 103ms/step - loss: 0.8822 - accuracy: 0.6688 - val_loss: 1.0294 - val_accuracy: 0.6241
# Epoch 25/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8753 - accuracy: 0.6771
# Epoch 00025: val_loss did not improve from 1.00049
# 898/897 [==============================] - 93s 103ms/step - loss: 0.8753 - accuracy: 0.6771 - val_loss: 1.0386 - val_accuracy: 0.6257
# Epoch 26/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8638 - accuracy: 0.6798
# Epoch 00026: val_loss did not improve from 1.00049
# 898/897 [==============================] - 93s 103ms/step - loss: 0.8638 - accuracy: 0.6798 - val_loss: 1.0103 - val_accuracy: 0.6272
# Epoch 27/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8596 - accuracy: 0.6786
# Epoch 00027: val_loss improved from 1.00049 to 0.98728, saving model to ./model/_mini_XCEPTION.27-0.64.hdf5
# 898/897 [==============================] - 94s 105ms/step - loss: 0.8596 - accuracy: 0.6786 - val_loss: 0.9873 - val_accuracy: 0.6371
# Epoch 28/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8448 - accuracy: 0.6861
# Epoch 00028: val_loss improved from 0.98728 to 0.94925, saving model to ./model/_mini_XCEPTION.28-0.65.hdf5
# 898/897 [==============================] - 94s 104ms/step - loss: 0.8448 - accuracy: 0.6861 - val_loss: 0.9493 - val_accuracy: 0.6510
# Epoch 29/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8381 - accuracy: 0.6878
# Epoch 00029: val_loss did not improve from 0.94925
# 898/897 [==============================] - 93s 103ms/step - loss: 0.8381 - accuracy: 0.6878 - val_loss: 0.9693 - val_accuracy: 0.6390
# Epoch 30/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8267 - accuracy: 0.6903
# Epoch 00030: val_loss did not improve from 0.94925
# 898/897 [==============================] - 93s 104ms/step - loss: 0.8267 - accuracy: 0.6903 - val_loss: 1.0035 - val_accuracy: 0.6339
# Epoch 31/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8168 - accuracy: 0.6995
# Epoch 00031: val_loss did not improve from 0.94925
# 898/897 [==============================] - 93s 104ms/step - loss: 0.8168 - accuracy: 0.6995 - val_loss: 0.9712 - val_accuracy: 0.6516
# Epoch 32/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8072 - accuracy: 0.7007
# Epoch 00032: val_loss did not improve from 0.94925
# 898/897 [==============================] - 92s 102ms/step - loss: 0.8072 - accuracy: 0.7007 - val_loss: 1.0158 - val_accuracy: 0.6385
# Epoch 33/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7976 - accuracy: 0.7038
# Epoch 00033: val_loss did not improve from 0.94925
# 898/897 [==============================] - 93s 103ms/step - loss: 0.7976 - accuracy: 0.7038 - val_loss: 1.0002 - val_accuracy: 0.6446
# Epoch 34/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7904 - accuracy: 0.7047
# Epoch 00034: val_loss did not improve from 0.94925
# 898/897 [==============================] - 93s 103ms/step - loss: 0.7904 - accuracy: 0.7047 - val_loss: 0.9677 - val_accuracy: 0.6438
# Epoch 35/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7797 - accuracy: 0.7109
# Epoch 00035: val_loss did not improve from 0.94925
# 898/897 [==============================] - 92s 103ms/step - loss: 0.7797 - accuracy: 0.7109 - val_loss: 0.9676 - val_accuracy: 0.6478
# Epoch 36/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7754 - accuracy: 0.7117
# Epoch 00036: val_loss did not improve from 0.94925
# 898/897 [==============================] - 93s 104ms/step - loss: 0.7754 - accuracy: 0.7117 - val_loss: 1.0198 - val_accuracy: 0.6396
# Epoch 37/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7623 - accuracy: 0.7176
# Epoch 00037: val_loss did not improve from 0.94925
# 898/897 [==============================] - 93s 104ms/step - loss: 0.7623 - accuracy: 0.7176 - val_loss: 1.0286 - val_accuracy: 0.6328
# Epoch 38/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7537 - accuracy: 0.7205
# Epoch 00038: val_loss improved from 0.94925 to 0.93930, saving model to ./model/_mini_XCEPTION.38-0.66.hdf5
# 898/897 [==============================] - 93s 103ms/step - loss: 0.7537 - accuracy: 0.7205 - val_loss: 0.9393 - val_accuracy: 0.6610
# Epoch 39/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7425 - accuracy: 0.7219
# Epoch 00039: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.7425 - accuracy: 0.7219 - val_loss: 0.9507 - val_accuracy: 0.6591
# Epoch 40/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7360 - accuracy: 0.7280
# Epoch 00040: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.7360 - accuracy: 0.7280 - val_loss: 0.9634 - val_accuracy: 0.6567
# Epoch 41/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7253 - accuracy: 0.7292
# Epoch 00041: val_loss did not improve from 0.93930
# 898/897 [==============================] - 92s 102ms/step - loss: 0.7253 - accuracy: 0.7292 - val_loss: 1.0603 - val_accuracy: 0.6321
# Epoch 42/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7147 - accuracy: 0.7348
# Epoch 00042: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.7147 - accuracy: 0.7348 - val_loss: 0.9934 - val_accuracy: 0.6549
# Epoch 43/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7107 - accuracy: 0.7379
# Epoch 00043: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.7107 - accuracy: 0.7379 - val_loss: 1.0061 - val_accuracy: 0.6523
# Epoch 44/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6991 - accuracy: 0.7415
# Epoch 00044: val_loss did not improve from 0.93930
# 898/897 [==============================] - 92s 102ms/step - loss: 0.6991 - accuracy: 0.7415 - val_loss: 0.9606 - val_accuracy: 0.6651
# Epoch 45/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6895 - accuracy: 0.7431
# Epoch 00045: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.6895 - accuracy: 0.7431 - val_loss: 0.9768 - val_accuracy: 0.6656
# Epoch 46/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.7475
# Epoch 00046: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.6805 - accuracy: 0.7475 - val_loss: 0.9719 - val_accuracy: 0.6624
# Epoch 47/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6697 - accuracy: 0.7502
# Epoch 00047: val_loss did not improve from 0.93930
# 898/897 [==============================] - 92s 102ms/step - loss: 0.6697 - accuracy: 0.7502 - val_loss: 1.0039 - val_accuracy: 0.6565
# Epoch 48/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6712 - accuracy: 0.7520
# Epoch 00048: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.6712 - accuracy: 0.7520 - val_loss: 0.9477 - val_accuracy: 0.6688
# Epoch 49/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6564 - accuracy: 0.7554
# Epoch 00049: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.6564 - accuracy: 0.7554 - val_loss: 1.0355 - val_accuracy: 0.6602
# Epoch 50/150
# 898/897 [==============================] - ETA: 0s - loss: 0.6510 - accuracy: 0.7567
# Epoch 00050: val_loss did not improve from 0.93930
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 898/897 [==============================] - 92s 102ms/step - loss: 0.6510 - accuracy: 0.7567 - val_loss: 1.0068 - val_accuracy: 0.6658
# Epoch 51/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5726 - accuracy: 0.7918
# Epoch 00051: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.5726 - accuracy: 0.7918 - val_loss: 0.9492 - val_accuracy: 0.6811
# Epoch 52/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.8024
# Epoch 00052: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.5376 - accuracy: 0.8024 - val_loss: 0.9691 - val_accuracy: 0.6804
# Epoch 53/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5267 - accuracy: 0.8071
# Epoch 00053: val_loss did not improve from 0.93930
# 898/897 [==============================] - 92s 103ms/step - loss: 0.5267 - accuracy: 0.8071 - val_loss: 0.9598 - val_accuracy: 0.6826
# Epoch 54/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.8093
# Epoch 00054: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.5186 - accuracy: 0.8093 - val_loss: 0.9742 - val_accuracy: 0.6831
# Epoch 55/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5074 - accuracy: 0.8141
# Epoch 00055: val_loss did not improve from 0.93930
# 898/897 [==============================] - 92s 103ms/step - loss: 0.5074 - accuracy: 0.8141 - val_loss: 0.9715 - val_accuracy: 0.6808
# Epoch 56/150
# 898/897 [==============================] - ETA: 0s - loss: 0.5004 - accuracy: 0.8159
# Epoch 00056: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 103ms/step - loss: 0.5004 - accuracy: 0.8159 - val_loss: 0.9841 - val_accuracy: 0.6829
# Epoch 57/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.8200
# Epoch 00057: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.4936 - accuracy: 0.8200 - val_loss: 0.9956 - val_accuracy: 0.6872
# Epoch 58/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.8206
# Epoch 00058: val_loss did not improve from 0.93930
# 898/897 [==============================] - 92s 102ms/step - loss: 0.4850 - accuracy: 0.8206 - val_loss: 1.0017 - val_accuracy: 0.6829
# Epoch 59/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.8221
# Epoch 00059: val_loss did not improve from 0.93930
# 898/897 [==============================] - 94s 104ms/step - loss: 0.4882 - accuracy: 0.8221 - val_loss: 0.9940 - val_accuracy: 0.6814
# Epoch 60/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.8241
# Epoch 00060: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 104ms/step - loss: 0.4809 - accuracy: 0.8241 - val_loss: 1.0183 - val_accuracy: 0.6832
# Epoch 61/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8250
# Epoch 00061: val_loss did not improve from 0.93930
# 898/897 [==============================] - 92s 102ms/step - loss: 0.4759 - accuracy: 0.8250 - val_loss: 1.0149 - val_accuracy: 0.6812
# Epoch 62/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.8272
# Epoch 00062: val_loss did not improve from 0.93930
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 898/897 [==============================] - 94s 104ms/step - loss: 0.4712 - accuracy: 0.8272 - val_loss: 1.0305 - val_accuracy: 0.6851
# Epoch 63/150
# 898/897 [==============================] - ETA: 0s - loss: 0.4676 - accuracy: 0.8294
# Epoch 00063: val_loss did not improve from 0.93930
# 898/897 [==============================] - 93s 103ms/step - loss: 0.4676 - accuracy: 0.8294 - val_loss: 1.0172 - val_accuracy: 0.6858

# %% [markdown]
# **Plot performance metrics.**

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
testloss = model.evaluate(xtest, ytest)
print("Test Loss " + str(testloss[0]))
print("Test Acc: " + str(testloss[1]))
trainloss = model.evaluate(xtrain, ytrain)
print("Train Loss " + str(trainloss[0]))
print("Train Acc: " + str(trainloss[1]))
# Out:
# 225/225 [==============================] - 5s 24ms/step - loss: 1.0172 - accuracy: 0.6858
# Test Loss 1.0171574354171753
# Test Acc: 0.6858456134796143
# 898/898 [==============================] - 22s 24ms/step - loss: 0.4307 - accuracy: 0.8425
# Train Loss 0.43074727058410645
# Train Acc: 0.8425232768058777

# %% [markdown]
# **Visualizing model architecture.**

# %%
plot_model(model, to_file='model.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %% [markdown]
# ## Testing on images

# %%
rrr=np.array(ytest)

# %%
classes=np.array(("Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"))

# %%
def pred(img,label):
   #img=cv2.imread('/kaggle/input/rrjjjj/zerf.jpg')
   #img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
   #img=cv2.resize(img,(48,48))
   #img=preprocess_input(img)
   #img=np.array(img).reshape(1,48,48,1)
   x=img.reshape(1,48,48,1)

   predicted_value=np.argmax(model.predict(x))
   print('The predicted classe is:  {}'.format(classes[predicted_value]))
   print('--------------------------------')
   print('The true classe is:  {}'.format(classes[label]))
   plt.imshow(img.reshape(48,48))

# %%
pred(xtest[1001],rrr[1001])
# Out:
# The predicted classe is:  Fear
# --------------------------------
# The true classe is:  Angry

# %%
pred(xtest[1203],rrr[1203])
# Out:
# The predicted classe is:  Fear
# --------------------------------
# The true classe is:  Angry

# %%
pred(xtest[1501],rrr[1501])
# Out:
# The predicted classe is:  Neutral
# --------------------------------
# The true classe is:  Neutral

# %%
pred(xtest[393],rrr[393])
# Out:
# The predicted classe is:  Angry
# --------------------------------
# The true classe is:  Angry

# %%
pred(xtest[401],rrr[401])
# Out:
# The predicted classe is:  Fear
# --------------------------------
# The true classe is:  Disgust

# %%
pred(xtest[450],rrr[450])
# Out:
# The predicted classe is:  Surprise
# --------------------------------
# The true classe is:  Happy

# %%
pred(xtest[7000],rrr[7000])
# Out:
# The predicted classe is:  Happy
# --------------------------------
# The true classe is:  Happy
